# %%
#uploading dataset file in collab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a14db5a5-8ba7-43d6-948f-0335a117a415" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a14db5a5-8ba7-43d6-948f-0335a117a415">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
#converting csv file into datafame
df = pd.read_csv("India_rainfall.csv")

# %%
df
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 109.1                 241.4                 284.2
# 1    1902                 104.0                 283.7                 202.6
# 2    1903                 114.8                 293.0                 279.6
# 3    1904                 158.8                 266.4                 210.4
# 4    1905                  88.7                 252.5                 202.6
# ..    ...                   ...                   ...                   ...
# 111  2012                 117.8                 250.2                 262.4
# 112  2013                 219.8                 310.0                 254.7
# 113  2014                  95.2                 261.1                 237.4
# 114  2015                 189.0                 240.8                 204.2
# 115  2016                 147.6                 309.2                 239.6
#
#      Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# ...

# %%
df.describe()
# Out:
#               YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  \
# count   116.000000            116.000000            116.000000
# mean   1958.500000            166.711207            294.135345
# std      33.630343             36.133349             41.531085
# min    1901.000000             85.700000            146.200000
# 25%    1929.750000            141.425000            273.575000
# 50%    1958.500000            167.250000            295.600000
# 75%    1987.250000            190.450000            322.400000
# max    2016.000000            277.200000            381.600000
#
#        Actual Rainfall: AUG  Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# count            116.000000             116.000000                 116.000000
# mean             260.920690             173.710345                 895.943966
# std               37.237717              37.492936                  92.796977
# min              189.800000              95.100000                 697.400000
# ...

# %% [markdown]
# # 1. For the given data find mean, standard deviation and variance in excel.

# %%
df.mean()
# Out:
# YEAR                              1958.500000
# Actual Rainfall: JUN               166.711207
# Actual Rainfall: JUL               294.135345
# Actual Rainfall: AUG               260.920690
# Actual Rainfall: SEPT              173.710345
# Actual Rainfall: JUN-SEPT          895.943966
# Departure Percentage: JUN           -0.562931
# Departure Percentage: JUL           -2.203448
# Departure Percentage: AUG            0.375000
# Departure Percentage: SEP           -1.219828
# Departure Percentage: JUN-SEPT      -0.976724
# dtype: float64

# %%
df.std()
# Out:
# YEAR                              33.630343
# Actual Rainfall: JUN              36.133349
# Actual Rainfall: JUL              41.531085
# Actual Rainfall: AUG              37.237717
# Actual Rainfall: SEPT             37.492936
# Actual Rainfall: JUN-SEPT         92.796977
# Departure Percentage: JUN         22.330344
# Departure Percentage: JUL         14.009717
# Departure Percentage: AUG         14.916037
# Departure Percentage: SEP         22.628705
# Departure Percentage: JUN-SEPT    10.031701
# dtype: float64

# %%
df.var()
# Out:
# YEAR                              1131.000000
# Actual Rainfall: JUN              1305.618917
# Actual Rainfall: JUL              1724.831001
# Actual Rainfall: AUG              1386.647568
# Actual Rainfall: SEPT             1405.720240
# Actual Rainfall: JUN-SEPT         8611.279007
# Departure Percentage: JUN          498.644266
# Departure Percentage: JUL          196.272162
# Departure Percentage: AUG          222.488152
# Departure Percentage: SEP          512.058299
# Departure Percentage: JUN-SEPT     100.635019
# dtype: float64

# %% [markdown]
# # 2. From the given data, take a sample and find mean, standard deviation and variance for population in excel. Also, validate Central Limit Theorem in excel and python as discussed in the class.

# %%
df
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 0    1901                 109.1                 241.4                 284.2
# 1    1902                 104.0                 283.7                 202.6
# 2    1903                 114.8                 293.0                 279.6
# 3    1904                 158.8                 266.4                 210.4
# 4    1905                  88.7                 252.5                 202.6
# ..    ...                   ...                   ...                   ...
# 111  2012                 117.8                 250.2                 262.4
# 112  2013                 219.8                 310.0                 254.7
# 113  2014                  95.2                 261.1                 237.4
# 114  2015                 189.0                 240.8                 204.2
# 115  2016                 147.6                 309.2                 239.6
#
#      Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# ...

# %%
sample1 = df.sample(10)
sample1
# Out:
#     YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 29  1930                 183.9                 307.2                 208.5
# 15  1916                 233.8                 301.5                 318.8
# 58  1959                 168.4                 374.3                 263.3
# 42  1943                 164.3                 324.3                 246.6
# 68  1969                 128.4                 314.0                 271.2
# 77  1978                 218.1                 298.8                 279.8
# 21  1922                 201.2                 326.1                 225.6
# 97  1998                 167.8                 296.5                 261.4
# 65  1966                 172.2                 251.3                 211.9
# 56  1957                 142.2                 289.9                 283.7
#
#     Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 29                  176.8                      876.4
# ...

# %%
sample1.mean()
# Out:
# YEAR                              1953.80
# Actual Rainfall: JUN               178.03
# Actual Rainfall: JUL               308.39
# Actual Rainfall: AUG               257.08
# Actual Rainfall: SEPT              186.76
# Actual Rainfall: JUN-SEPT          935.43
# Departure Percentage: JUN            4.26
# Departure Percentage: JUL            2.43
# Departure Percentage: AUG           -0.93
# Departure Percentage: SEP            7.37
# Departure Percentage: JUN-SEPT       2.71
# dtype: float64

# %%
sample1.std()
# Out:
# YEAR                              25.990597
# Actual Rainfall: JUN              32.410597
# Actual Rainfall: JUL              31.315153
# Actual Rainfall: AUG              34.629750
# Actual Rainfall: SEPT             33.172351
# Actual Rainfall: JUN-SEPT         80.195082
# Departure Percentage: JUN         18.128627
# Departure Percentage: JUL          9.986552
# Departure Percentage: AUG         15.162824
# Departure Percentage: SEP         18.439936
# Departure Percentage: JUN-SEPT     8.439780
# dtype: float64

# %%
sample2 = df.sample(10)
sample2
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 17   1918                 206.3                 180.4                 240.7
# 8    1909                 205.0                 318.1                 239.9
# 35   1936                 252.1                 300.6                 243.8
# 108  2009                  85.7                 280.6                 192.5
# 98   1999                 175.2                 273.5                 223.7
# 114  2015                 189.0                 240.8                 204.2
# 80   1981                 165.8                 309.8                 228.2
# 105  2006                 141.8                 287.6                 281.3
# 74   1975                 173.8                 314.4                 296.6
# 70   1971                 240.6                 278.4                 256.7
#
#      Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 17                   109.1                      736.5
# ...

# %%
sample2.mean()
# Out:
# YEAR                              1971.90
# Actual Rainfall: JUN               183.53
# Actual Rainfall: JUL               278.42
# Actual Rainfall: AUG               240.76
# Actual Rainfall: SEPT              167.18
# Actual Rainfall: JUN-SEPT          865.80
# Departure Percentage: JUN            9.89
# Departure Percentage: JUL           -7.06
# Departure Percentage: AUG           -6.61
# Departure Percentage: SEP           -3.98
# Departure Percentage: JUN-SEPT      -3.31
# dtype: float64

# %%
sample2.std()
# Out:
# YEAR                               38.549968
# Actual Rainfall: JUN               48.026267
# Actual Rainfall: JUL               41.475744
# Actual Rainfall: AUG               31.867999
# Actual Rainfall: SEPT              35.131619
# Actual Rainfall: JUN-SEPT         104.277237
# Departure Percentage: JUN          28.204785
# Departure Percentage: JUL          16.417146
# Departure Percentage: AUG          14.311258
# Departure Percentage: SEP          21.079574
# Departure Percentage: JUN-SEPT     13.039892
# dtype: float64

# %%
sample3 = df.sample(10)
sample3
# Out:
#     YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 94  1995                 135.1                 313.0                 259.8
# 11  1912                 104.9                 337.6                 267.7
# 88  1989                 194.7                 318.6                 235.7
# 21  1922                 201.2                 326.1                 225.6
# 63  1964                 179.8                 358.3                 288.4
# 4   1905                  88.7                 252.5                 202.6
# 54  1955                 171.9                 249.9                 317.2
# 6   1907                 150.1                 223.5                 311.6
# 82  1983                 152.2                 285.5                 309.5
# 91  1992                 126.3                 243.1                 289.1
#
#     Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 94                  192.4                      900.3
# ...

# %%
sample3.mean()
# Out:
# YEAR                              1952.40
# Actual Rainfall: JUN               150.49
# Actual Rainfall: JUL               290.81
# Actual Rainfall: AUG               270.72
# Actual Rainfall: SEPT              181.27
# Actual Rainfall: JUN-SEPT          893.30
# Departure Percentage: JUN           -9.39
# Departure Percentage: JUL           -2.99
# Departure Percentage: AUG            5.87
# Departure Percentage: SEP            3.41
# Departure Percentage: JUN-SEPT      -0.32
# dtype: float64

# %%
sample3.std()
# Out:
# YEAR                               37.512072
# Actual Rainfall: JUN               37.364613
# Actual Rainfall: JUL               46.224848
# Actual Rainfall: AUG               39.464155
# Actual Rainfall: SEPT              46.827106
# Actual Rainfall: JUN-SEPT         100.848026
# Departure Percentage: JUN          20.833277
# Departure Percentage: JUL          13.854759
# Departure Percentage: AUG          16.655466
# Departure Percentage: SEP          26.950261
# Departure Percentage: JUN-SEPT      9.721660
# dtype: float64

# %%
sample4 = df.sample(10)
sample4
# Out:
#      YEAR  Actual Rainfall: JUN  Actual Rainfall: JUL  Actual Rainfall: AUG  \
# 69   1970                 212.1                 253.6                 319.3
# 52   1953                 167.7                 336.2                 302.7
# 51   1952                 167.8                 286.5                 262.1
# 37   1938                 277.2                 311.0                 253.6
# 109  2010                 138.1                 300.7                 274.7
# 63   1964                 179.8                 358.3                 288.4
# 28   1929                 192.5                 296.3                 246.8
# 31   1932                 136.8                 337.6                 238.1
# 89   1990                 191.7                 280.4                 294.5
# 15   1916                 233.8                 301.5                 318.8
#
#      Actual Rainfall: SEPT  Actual Rainfall: JUN-SEPT  \
# 69                   213.7                      998.7
# ...

# %%
sample4.mean()
# Out:
# YEAR                              1955.40
# Actual Rainfall: JUN               189.75
# Actual Rainfall: JUL               306.21
# Actual Rainfall: AUG               279.90
# Actual Rainfall: SEPT              179.17
# Actual Rainfall: JUN-SEPT          955.01
# Departure Percentage: JUN           10.00
# Departure Percentage: JUL            0.54
# Departure Percentage: AUG            6.75
# Departure Percentage: SEP           -0.05
# Departure Percentage: JUN-SEPT       3.98
# dtype: float64

# %%
sample4.std()
# Out:
# YEAR                              29.025659
# Actual Rainfall: JUN              42.995122
# Actual Rainfall: JUL              30.901724
# Actual Rainfall: AUG              29.343256
# Actual Rainfall: SEPT             34.755305
# Actual Rainfall: JUN-SEPT         75.211560
# Departure Percentage: JUN         24.886230
# Departure Percentage: JUL          9.443069
# Departure Percentage: AUG         13.073149
# Departure Percentage: SEP         20.475962
# Departure Percentage: JUN-SEPT     7.798689
# dtype: float64

# %%
#mean of Actual Rainfall: JUN-SEPT 
sample_mean = (935.43 + 865.80 + 893.30 + 955.01)/4
sample_mean
# Out:
# 912.385
# 912.385

# %%
#standard deviation of Actual Rainfall: JUN-SEPT 
print(np.std([80.195082,104.277237,100.848026,75.211560]))
# Out:
# 12.612323421349778

# %% [markdown]
# # 5. Perform One-way and two-way ANOVA on the dataset as discussed in class using formulae as well as ANOVA function in excel.

# %%
pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from scipy.stats import f_oneway

# %%
#perform one-way ANOVA
f_oneway(sample1, sample2, sample3, sample4)
# Out:
# F_onewayResult(statistic=array([0.75082932, 1.81658119, 1.36668331, 2.50865606, 0.47531163,
#        1.96480657, 1.52876608, 1.07524048, 1.78361802, 0.48634673,
#        1.07252276]), pvalue=array([0.52906404, 0.16158533, 0.26848714, 0.07427667, 0.7014245 ,
#        0.13668949, 0.22366883, 0.3718054 , 0.167716  , 0.69389908,
#        0.37292563]))

# %% [markdown]
# # 6. Perform t-test on the dataset as discussed in class using t-test function in excel.

# %%
pip install statsmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from statsmodels.stats.weightstats import ttest_ind

# %%
ttest_ind(sample1, sample2)
# Out:
# (array([-1.23108997, -0.30018502,  1.82362027,  1.09661451,  1.28145435,
#          1.67382741, -0.53100048,  1.5617218 ,  0.86147338,  1.28154157,
#          1.22559232]),
#  array([0.23413322, 0.76747527, 0.08485938, 0.28726496, 0.21629675,
#         0.11145263, 0.60190971, 0.13576321, 0.40030832, 0.2162668 ,
#         0.23614687]),
#  18.0)

# %%
alpha = 0.05
claimed_value = 111.875
from scipy.stats import ttest_1samp
x = [80.195082,104.277237,100.848026,75.211560]
ttest_1samp(x,popmean = claimed_value)
# Out:
# TtestResult(statistic=-2.985832866498043, pvalue=0.058324417643596714, df=3)
